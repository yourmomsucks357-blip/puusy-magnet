# %%
# !git clone https://github.com/yourmomsucks357-blip/cybersecurity-toolkit.git
import os; os.chdir('cybersecurity-toolkit')
# !pip install -q -r requirements.txt
# !python go.py
